# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import pandapower as pp
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pp_heig_simulation as pp_sim
import pickle

# %% [markdown]
# Import pickle ("trey_net_student.p")

# %%
# Load the pandapower network from the pickle file
net_trey = pp.from_pickle("input-data/trey_net_student.p")

# quick inspection
print(type(net_trey))
print(net_trey)
# Out:
# <class 'pandapower.auxiliary.pandapowerNet'>
# This pandapower network includes the following parameter tables:
#    - bus (13 elements)
#    - load (12 elements)
#    - ext_grid (1 element)
#    - line (11 elements)
#    - trafo (1 element)

# %% [markdown]
# Design of network

# %%
# Bus 
net_trey.bus
# Out:
#             name   type   zone  in_service  geo
# 0     STMT003438     PQ  Trafo        True  NaN
# 1     CDBT004764     PQ  North        True  NaN
# 2     CDBT003746     PQ  North        True  NaN
# 3     CDBT004760     PQ  North        True  NaN
# 4     CDBT012139     PQ  North        True  NaN
# 5     CDBT900784     PQ  North        True  NaN
# 6     CDBT901452     PQ  South        True  NaN
# 7     CDBT004774     PQ  South        True  NaN
# 8     CDBT901604     PQ  South        True  NaN
# 9     CDBT016055     PQ  South        True  NaN
# 10            N1     PQ  South        True  NaN
# 11         60437     PQ  South        True  NaN
# 12  STMT003438HV  Slack  Trafo        True  NaN

# %%
# load
net_trey.load
# Out:
#           name  bus  const_z_p_percent  const_z_q_percent  const_i_p_percent  \
# 0   STMT003438    0                0.0                0.0                0.0
# 1   CDBT004764    1                0.0                0.0                0.0
# 2   CDBT003746    2                0.0                0.0                0.0
# 3   CDBT004760    3                0.0                0.0                0.0
# 4   CDBT012139    4                0.0                0.0                0.0
# 5   CDBT900784    5                0.0                0.0                0.0
# 6   CDBT901452    6                0.0                0.0                0.0
# 7   CDBT004774    7                0.0                0.0                0.0
# 8   CDBT901604    8                0.0                0.0                0.0
# 9   CDBT016055    9                0.0                0.0                0.0
# 10          N1   10                0.0                0.0                0.0
# 11       60437   11                0.0                0.0                0.0
#
#     const_i_q_percent  sn_mva  in_service type
# 0                 0.0     NaN        True  wye
# 1                 0.0     NaN        True  wye
# 2                 0.0     NaN        True  wye
# 3                 0.0     NaN        True  wye
# 4                 0.0     NaN        True  wye
# 5                 0.0     NaN        True  wye
# 6                 0.0     NaN        True  wye
# 7                 0.0     NaN        True  wye
# 8                 0.0     NaN        True  wye
# 9                 0.0     NaN        True  wye
# 10                0.0     NaN        True  wye
# 11                0.0     NaN        True  wye

# %%
# ext_grid
net_trey.ext_grid
# Out:
#          name  vm_pu  va_degree  slack_weight  s_sc_max_mva s_sc_min_mva  \
# 0  ext_grid_0    1.0        0.0           1.0         100.0         None
#
#   rx_min  rx_max  r0x0_max  x0x_max  in_service
# 0   None     0.1       2.0      2.0        True

# %%
# Line
net_trey.line
# Out:
#               name  from_bus  to_bus  g_us_per_km   df std_type  in_service  \
# 0     GKN3x150_150         0       1          0.0  1.0     None        True
# 1   GKN3x150_150_2         1       2          0.0  1.0     None        True
# 2       GKN3X95_95         1       3          0.0  1.0     None        True
# 3       GKT3X50_50         3       4          0.0  1.0     None        True
# 4     GKT3X50_50_2         4       5          0.0  1.0     None        True
# 5   GKN3x150_150_3         0       6          0.0  1.0     None        True
# 6     GKN3X95_95_2         6       7          0.0  1.0     None        True
# 7   GKN3x150_150_4         7       8          0.0  1.0     None        True
# 8       GKN3X50_50         7       9          0.0  1.0     None        True
# 9     GKN3X50_50_2         6      10          0.0  1.0     None        True
# 10    GKN3X240_240         0      11          0.0  1.0     None        True
#
#     geo
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN

# %%
# tranformer
net_trey.trafo
# Out:
#          name  hv_bus  lv_bus  sn_mva  vn_hv_kv  vn_lv_kv  vk_percent  \
# 0  STMT003438      12       0    0.63      18.3      0.42         4.0
#
#    vkr_percent  pfe_kw  i0_percent  ... tap_min  tap_max  tap_step_percent  \
# 0         0.42    0.65         1.8  ...    -3.0      3.0               2.0
#
#    tap_step_degree  tap_pos  parallel  std_type   df  in_service  \
# 0              0.0     -3.0         1      None  1.0        True
#
#    tap_changer_type
# 0             Ratio
#
# [1 rows x 29 columns]
