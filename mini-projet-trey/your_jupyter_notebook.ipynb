# %%
# Import necessary libraries

import numpy as np
import pandas as pd
import pandapower as pp
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pp_heig_simulation as pp_sim
import pickle

# %% [markdown]
# Import pickle ("trey_net_student.p")

# %%
# Load the pandapower network from the pickle file
net_trey = pp.from_pickle("input-data/trey_net_student.p")

# quick inspection
print(type(net_trey))
print(net_trey)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 net_trey = pp.from_pickle("input-data/trey_net_student.p")
#       3 # quick inspection
#       4 print(type(net_trey))
#
# File c:\HEIG_VD\3eme\RéseauHT\Labo\rhtlab\.venv\Lib\site-packages\pandapower\file_io.py:168, in from_pickle(filename, convert)
#     165 transform_net_with_df_and_geo(net, ["bus_geodata"], ["line_geodata"])
#     167 if convert:
# --> 168     convert_format(net)
#     170     # compare pandapowerNet-format_version and package-version
#     171     # check if installed pandapower version is older than imported network file
#     172     check_net_version(net)
#
# File c:\HEIG_VD\3eme\RéseauHT\Labo\rhtlab\.venv\Lib\site-packages\pandapower\convert_format.py:37, in convert_format(net, elements_to_deserialize)
#      35 _add_nominal_power(net)
#      36 _add_missing_tables(net)
# ---> 37 _rename_columns(net, elements_to_deserialize)
#      38 _add_missing_columns(net, elements_to_deserialize)
#      39 _create_seperate_cost_tables(net, elements_to_deserialize)
#
# File c:\HEIG_VD\3eme\RéseauHT\Labo\rhtlab\.venv\Lib\site-packages\pandapower\convert_format.py:312, in _rename_columns(net, elements_to_deserialize)
#     310 if _check_elements_to_deserialize('controller', elements_to_deserialize):
#     311     if "controller" in net:
# --> 312         net["controller"] = net["controller"].rename(columns={"controller": "object"})
#     314 if _check_elements_to_deserialize('res_line_3ph', elements_to_deserialize):
#     315     if "p_a_l_mw" in net.res_line_3ph:
#
# AttributeError: 'NoneType' object has no attribute 'rename'
